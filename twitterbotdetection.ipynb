# %%
import pandas as pd
import numpy as np

# %%
training_data=pd.read_csv(r'C:\Users\YUVANSHU\Downloads\twitter-bot-detection-master\kaggle_data\training_data_2_csv_UTF.csv')

# %%
bots = training_data[training_data.bot==1]
nonbots = training_data[training_data.bot==0]

# %%
nonbots
# Out:
#                id     id_str      screen_name                 location  \
# 1321   34716038.0   34716038      aaroncarter   Sony Recording Artist
# 1322    3013511.0    3013511   michellebranch                      NaN
# 1323   56237623.0   56237623  stronginmyfaith                      NaN
# 1324   27964284.0   27964284  Jessicaveronica           5th Dimension
# 1325  552876065.0  552876065       resargento                   brasil
# ...           ...        ...              ...                      ...
# 2792  236209129.0  236209129    leslieberland                      NaN
# 2793  254503881.0  254503881     SamuelsPants              brooklyn NY
# 2794   15485441.0   15485441      jimmyfallon       New York, New York
# 2795  751386872.0  751386872   LocalAlligator  England, United Kingdom
# 2796   19929362.0   19929362     RepJoeBarton                Ennis, TX
#
#                                             description  \
# 1321  NEW AARON CARTER MUSIC DOWNLOAD LINK LÌüVÌÇ EP...
# 1322  singer/songwriter, hopeless romantic, drinker ...
# 1323                                                NaN
# 1324  @TheVeronicas ‰Ü  Wanderer, worshiper, if you ...
# 1325            meio ogra mas o coraí_í£o í© de mocinha
# ...                                                 ...
# 2792  Twitter CMO. Favorite title: Mama. Never, ever...
# 2793  I live in brooklyn, I'm a bike messenger, I pl...
# 2794                                     astrophysicist
# 2795  I'm quite out of my mind, actually, but people...
# 2796  I work for the people of the 6th District of T...
#
#                           url  followers_count  friends_count  listed_count  \
# 1321                      NaN           571310          76070          4909
# 1322  https://t.co/2vSKw7cmzC           292385            963          6076
# 1323                      NaN                1              7             0
# 1324  https://t.co/U6yNZoDZfu           222659            352          3261
# 1325                      NaN              646            446             2
# ...                       ...              ...            ...           ...
# 2792                      NaN            18998           2005           425
# 2793   http://t.co/CQkADdjfaw               32             54             0
# 2794   http://t.co/fgp5RYqr3T         45044433           7451         68157
# 2795                      NaN               16             64             1
# 2796   http://t.co/UcrfIiWGdl            22490            308          1342
#
#                           created_at  ...  lang  \
# 1321  Thu Apr 23 20:15:49 +0000 2009  ...    en
# 1322  Fri Mar 30 20:58:59 +0000 2007  ...    en
# 1323                  7/13/2009 0:38  ...    en
# 1324  Tue Mar 31 21:12:33 +0000 2009  ...    en
# 1325                 4/13/2012 17:37  ...    pt
# ...                              ...  ...   ...
# 2792                  1/10/2011 2:06  ...    en
# 2793  Sat Feb 19 12:12:42 +0000 2011  ...    en
# 2794                 7/18/2008 19:46  ...    en
# 2795                 8/11/2012 14:53  ...    en
# 2796  Mon Feb 02 20:30:20 +0000 2009  ...    en
#
#                                                  status  default_profile  \
# 1321  {u'contributors': None, u'truncated': False, u...            False
# 1322  {u'contributors': None, u'truncated': False, u...            False
# 1323  Status(contributors=None, truncated=False, tex...             True
# 1324  {u'contributors': None, u'truncated': False, u...            False
# 1325                                                NaN            False
# ...                                                 ...              ...
# 2792  RT @StationCDRKelly: Dreaming of napping in sp...            False
# 2793  {'geo': None, 'in_reply_to_status_id': None, '...             True
# 2794  Status(contributors=None, truncated=False, tex...            False
# 2795  {'created_at': 'Sun Feb 26 15:51:57 +0000 2017...            False
# 2796  {u'contributors': None, u'truncated': False, u...             True
#
#      default_profile_image has_extended_profile                name  bot  \
# 1321                 False                 True        Aaron Carter    0
# 1322                 False                False     Michelle Branch    0
# 1323                  True                False     laurie lindeman    0
# 1324                 False                False    Jessica Veronica    0
# 1325                 False                False             rebosta    0
# ...                    ...                  ...                 ...  ...
# 2792                 False                 True      Leslie Berland    0
# 2793                 False                False  Samuel Littlefield    0
# 2794                 False                False        jimmy fallon    0
# 2795                 False                 True      Tammas Foxdene    0
# 2796                 False                 True          Joe Barton    0
#
#      screen_name_binary location_binary  verified_binary
# 1321               True            True             True
# 1322               True           False             True
# 1323               True           False            False
# 1324               True            True             True
# 1325               True            True            False
# ...                 ...             ...              ...
# 2792               True           False            False
# 2793               True            True            False
# 2794               True            True             True
# 2795               True            True            False
# 2796               True            True             True
#
# [1476 rows x 23 columns]

# %%
condition = (bots.screen_name.str.contains("bot", case=False)==True)|(bots.description.str.contains("bot", case=False)==True)|(bots.location.isnull())|(bots.verified==False)

bots['screen_name_binary'] = (bots.screen_name.str.contains("bot", case=False)==True)
bots['location_binary'] = (bots.location.isnull())
bots['verified_binary'] = (bots.verified==False)
bots.shape
# Out:
# C:\Users\YUVANSHU\AppData\Local\Temp\ipykernel_25788\4108726507.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bots['screen_name_binary'] = (bots.screen_name.str.contains("bot", case=False)==True)
# C:\Users\YUVANSHU\AppData\Local\Temp\ipykernel_25788\4108726507.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bots['location_binary'] = (bots.location.isnull())
# C:\Users\YUVANSHU\AppData\Local\Temp\ipykernel_25788\4108726507.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bots['verified_binary'] = (bots.verified==False)
# (1321, 23)

# %%
condition = (nonbots.screen_name.str.contains("bot", case=False)==False)| (nonbots.description.str.contains("bot", case=False)==False) |(nonbots.location.isnull()==False)|(nonbots.verified==True)

nonbots['screen_name_binary'] = (nonbots.screen_name.str.contains("bot", case=False)==False)
nonbots['location_binary'] = (nonbots.location.isnull()==False)
nonbots['verified_binary'] = (nonbots.verified==True)

nonbots.shape
# Out:
# C:\Users\YUVANSHU\AppData\Local\Temp\ipykernel_25788\1062836795.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonbots['screen_name_binary'] = (nonbots.screen_name.str.contains("bot", case=False)==False)
# C:\Users\YUVANSHU\AppData\Local\Temp\ipykernel_25788\1062836795.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonbots['location_binary'] = (nonbots.location.isnull()==False)
# C:\Users\YUVANSHU\AppData\Local\Temp\ipykernel_25788\1062836795.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nonbots['verified_binary'] = (nonbots.verified==True)
# (1476, 23)

# %%
df = pd.concat([bots, nonbots])
df.shape
# Out:
# (2797, 23)

# %%
df.corr(method='spearman')
# Out:
# C:\Users\YUVANSHU\AppData\Local\Temp\ipykernel_25788\1222267885.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='spearman')
#                              id  followers_count  friends_count  listed_count  \
# id                     1.000000        -0.672925      -0.402346     -0.615005
# followers_count       -0.672925         1.000000       0.375522      0.896126
# friends_count         -0.402346         0.375522       1.000000      0.204403
# listed_count          -0.615005         0.896126       0.204403      1.000000
# favourites_count      -0.439430         0.457363       0.641529      0.349059
# verified              -0.611899         0.709732       0.356452      0.694340
# statuses_count        -0.451945         0.649117       0.111118      0.684976
# default_profile        0.522990        -0.496899      -0.296358     -0.447376
# default_profile_image  0.166601        -0.293838      -0.097607     -0.269035
# bot                    0.652131        -0.468430      -0.483105     -0.318445
# screen_name_binary    -0.576100         0.458213       0.342145      0.338698
# location_binary       -0.228328         0.189675       0.082692      0.188797
# verified_binary        0.150100         0.130717      -0.210592      0.281360
#
#                        favourites_count  verified  statuses_count  \
# id                            -0.439430 -0.611899       -0.451945
# followers_count                0.457363  0.709732        0.649117
# friends_count                  0.641529  0.356452        0.111118
# listed_count                   0.349059  0.694340        0.684976
# favourites_count               1.000000  0.394227        0.295108
# verified                       0.394227  1.000000        0.333278
# statuses_count                 0.295108  0.333278        1.000000
# default_profile               -0.348043 -0.404650       -0.375918
# default_profile_image         -0.226956 -0.132298       -0.289999
# bot                           -0.526228 -0.508555       -0.089018
# screen_name_binary             0.408864  0.434177        0.162213
# location_binary                0.120941  0.191922        0.105333
# verified_binary               -0.220894  0.346505        0.207384
#
#                        default_profile  default_profile_image       bot  \
# id                            0.522990               0.166601  0.652131
# followers_count              -0.496899              -0.293838 -0.468430
# friends_count                -0.296358              -0.097607 -0.483105
# listed_count                 -0.447376              -0.269035 -0.318445
# favourites_count             -0.348043              -0.226956 -0.526228
# verified                     -0.404650              -0.132298 -0.508555
# statuses_count               -0.375918              -0.289999 -0.089018
# default_profile               1.000000               0.246979  0.407748
# default_profile_image         0.246979               1.000000  0.139669
# bot                           0.407748               0.139669  1.000000
# screen_name_binary           -0.377572              -0.166388 -0.843429
# location_binary              -0.138378               0.000596 -0.266342
# verified_binary               0.072351               0.033021  0.606771
#
#                        screen_name_binary  location_binary  verified_binary
# id                              -0.576100        -0.228328         0.150100
# followers_count                  0.458213         0.189675         0.130717
# friends_count                    0.342145         0.082692        -0.210592
# listed_count                     0.338698         0.188797         0.281360
# favourites_count                 0.408864         0.120941        -0.220894
# verified                         0.434177         0.191922         0.346505
# statuses_count                   0.162213         0.105333         0.207384
# default_profile                 -0.377572        -0.138378         0.072351
# default_profile_image           -0.166388         0.000596         0.033021
# bot                             -0.843429        -0.266342         0.606771
# screen_name_binary               1.000000         0.247107        -0.502677
# location_binary                  0.247107         1.000000        -0.099474
# verified_binary                 -0.502677        -0.099474         1.000000

# %%
training_data=pd.read_csv(r'C:\Users\YUVANSHU\Downloads\twitter-bot-detection-master\kaggle_data\training_data_2_csv_UTF.csv')

bag_of_words_bot = r'bot|b0t|cannabis|tweet me|mishear|follow me|updates every|gorilla|yes_ofc|forget' \
                    r'expos|kill|clit|bbb|butt|fuck|XXX|sex|truthe|fake|anony|free|virus|funky|RNA|kuck|jargon' \
                    r'nerd|swag|jack|bang|bonsai|chick|prison|paper|pokem|xx|freak|ffd|dunia|clone|genie|bbb' \
                    r'ffd|onlyman|emoji|joke|troll|droop|free|every|wow|cheese|yeah|bio|magic|wizard|face'
            
training_data['screen_name_binary'] = training_data.screen_name.str.contains(bag_of_words_bot, case=False, na=False)
training_data['name_binary'] = training_data.name.str.contains(bag_of_words_bot, case=False, na=False)
training_data['description_binary'] = training_data.description.str.contains(bag_of_words_bot, case=False, na=False)
training_data['status_binary'] = training_data.status.str.contains(bag_of_words_bot, case=False, na=False)

# %%
training_data
# Out:
#                 id                id_str       screen_name  \
# 0     8.160000e+17  "815745789754417152"  "HoustonPokeMap"
# 1     4.843621e+09            4843621225         kernyeahx
# 2     4.303727e+09            4303727112   mattlieberisbot
# 3     3.063139e+09            3063139353         sc_papers
# 4     2.955142e+09            2955142070      lucarivera16
# ...            ...                   ...               ...
# 2792  2.362091e+08             236209129     leslieberland
# 2793  2.545039e+08             254503881      SamuelsPants
# 2794  1.548544e+07              15485441       jimmyfallon
# 2795  7.513869e+08             751386872    LocalAlligator
# 2796  1.992936e+07              19929362      RepJoeBarton
#
#                        location  \
# 0                 "Houston, TX"
# 1     Templeville town, MD, USA
# 2                           NaN
# 3                           NaN
# 4         Dublin, United States
# ...                         ...
# 2792                        NaN
# 2793                brooklyn NY
# 2794         New York, New York
# 2795    England, United Kingdom
# 2796                  Ennis, TX
#
#                                             description  \
# 0     "Rare and strong PokŽmon in Houston, TX. See m...
# 1     From late 2014 Socium Marketplace will make sh...
# 2     Inspired by the smart, funny folks at @replyal...
# 3                                                   NaN
# 4                Inspiring cooks everywhere since 1956.
# ...                                                 ...
# 2792  Twitter CMO. Favorite title: Mama. Never, ever...
# 2793  I live in brooklyn, I'm a bike messenger, I pl...
# 2794                                     astrophysicist
# 2795  I'm quite out of my mind, actually, but people...
# 2796  I work for the people of the 6th District of T...
#
#                             url  followers_count  friends_count  listed_count  \
# 0     "https://t.co/dnWuDbFRkt"             1291              0            10
# 1                           NaN                1            349             0
# 2       https://t.co/P1e1o0m4KC             1086              0            14
# 3                           NaN               33              0             8
# 4                           NaN               11            745             0
# ...                         ...              ...            ...           ...
# 2792                        NaN            18998           2005           425
# 2793     http://t.co/CQkADdjfaw               32             54             0
# 2794     http://t.co/fgp5RYqr3T         45044433           7451         68157
# 2795                        NaN               16             64             1
# 2796     http://t.co/UcrfIiWGdl            22490            308          1342
#
#                             created_at  ...  \
# 0     "Mon Jan 02 02:25:26 +0000 2017"  ...
# 1                        2/1/2016 7:37  ...
# 2       Fri Nov 20 18:53:22 +0000 2015  ...
# 3                      2/25/2015 20:11  ...
# 4                       1/1/2015 17:44  ...
# ...                                ...  ...
# 2792                    1/10/2011 2:06  ...
# 2793    Sat Feb 19 12:12:42 +0000 2011  ...
# 2794                   7/18/2008 19:46  ...
# 2795                   8/11/2012 14:53  ...
# 2796    Mon Feb 02 20:30:20 +0000 2009  ...
#
#                                                  status  default_profile  \
# 0     {\r      "created_at": "Sun Mar 12 15:44:04 +0...             True
# 1                                                   NaN             True
# 2     {'retweeted': False, 'is_quote_status': False,...             True
# 3     Construction of human anti-tetanus single-chai...             True
# 4                                                   NaN            False
# ...                                                 ...              ...
# 2792  RT @StationCDRKelly: Dreaming of napping in sp...            False
# 2793  {'geo': None, 'in_reply_to_status_id': None, '...             True
# 2794  Status(contributors=None, truncated=False, tex...            False
# 2795  {'created_at': 'Sun Feb 26 15:51:57 +0000 2017...            False
# 2796  {u'contributors': None, u'truncated': False, u...             True
#
#       default_profile_image has_extended_profile                  name  bot  \
# 0                     False                False  "Houston PokŽ Alert"    1
# 1                     False                False           Keri Nelson    1
# 2                     False                False    Matt Lieber Is Bot    1
# 3                      True                False    single cell papers    1
# 4                     False                False          lucarivera16    1
# ...                     ...                  ...                   ...  ...
# 2792                  False                 True        Leslie Berland    0
# 2793                  False                False    Samuel Littlefield    0
# 2794                  False                False          jimmy fallon    0
# 2795                  False                 True        Tammas Foxdene    0
# 2796                  False                 True            Joe Barton    0
#
#       screen_name_binary name_binary description_binary  status_binary
# 0                   True       False              False           True
# 1                   True       False              False          False
# 2                   True        True               True           True
# 3                   True        True              False          False
# 4                  False       False               True          False
# ...                  ...         ...                ...            ...
# 2792               False       False              False          False
# 2793               False       False               True          False
# 2794               False       False              False          False
# 2795               False       False              False          False
# 2796               False       False              False          False
#
# [2797 rows x 24 columns]

# %%
training_data['listed_count_binary'] = (training_data.listed_count>20000)==False
features = ['screen_name_binary', 'name_binary', 'description_binary', 'status_binary', 'verified', 'followers_count', 'friends_count', 'statuses_count', 'listed_count_binary', 'bot']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn.model_selection import train_test_split

X = training_data[features].iloc[:,:-1]
y = training_data[features].iloc[:,-1]

dt = DecisionTreeClassifier(criterion='entropy', min_samples_leaf=50, min_samples_split=10)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

dt = dt.fit(X_train, y_train)
y_pred_train = dt.predict(X_train)
y_pred_test = dt.predict(X_test)

print("Trainig Accuracy: %.5f" %accuracy_score(y_train, y_pred_train))
print("Test Accuracy: %.5f" %accuracy_score(y_test, y_pred_test))
# Out:
# Trainig Accuracy: 0.88707
# Test Accuracy: 0.87857

# %%
y_pred_train
# Out:
# array([0, 1, 1, ..., 0, 0, 1], dtype=int64)

# %%
X_train
# Out:
#       screen_name_binary  name_binary  description_binary  status_binary  \
# 1508               False        False               False          False
# 412                 True         True                True          False
# 899                False        False               False          False
# 882                False        False                True          False
# 1091                True         True                True           True
# ...                  ...          ...                 ...            ...
# 599                 True        False                True          False
# 1599               False         True                True           True
# 1361               False        False               False           True
# 1547               False        False               False          False
# 863                 True         True                True          False
#
#       verified  followers_count  friends_count  statuses_count  \
# 1508     False              328           1875            3335
# 412      False               50              0             926
# 899      False              364              0           25220
# 882      False               62              1            1760
# 1091     False              320              4            5570
# ...        ...              ...            ...             ...
# 599      False             1479              3           32440
# 1599     False              228             64            1015
# 1361     False              113            280            4538
# 1547     False               22            102              26
# 863      False              261              0            3410
#
#       listed_count_binary
# 1508                 True
# 412                  True
# 899                  True
# 882                  True
# 1091                 True
# ...                   ...
# 599                  True
# 1599                 True
# 1361                 True
# 1547                 True
# 863                  True
#
# [1957 rows x 9 columns]

# %%
training_data
# Out:
#                 id                id_str       screen_name  \
# 0     8.160000e+17  "815745789754417152"  "HoustonPokeMap"
# 1     4.843621e+09            4843621225         kernyeahx
# 2     4.303727e+09            4303727112   mattlieberisbot
# 3     3.063139e+09            3063139353         sc_papers
# 4     2.955142e+09            2955142070      lucarivera16
# ...            ...                   ...               ...
# 2792  2.362091e+08             236209129     leslieberland
# 2793  2.545039e+08             254503881      SamuelsPants
# 2794  1.548544e+07              15485441       jimmyfallon
# 2795  7.513869e+08             751386872    LocalAlligator
# 2796  1.992936e+07              19929362      RepJoeBarton
#
#                        location  \
# 0                 "Houston, TX"
# 1     Templeville town, MD, USA
# 2                           NaN
# 3                           NaN
# 4         Dublin, United States
# ...                         ...
# 2792                        NaN
# 2793                brooklyn NY
# 2794         New York, New York
# 2795    England, United Kingdom
# 2796                  Ennis, TX
#
#                                             description  \
# 0     "Rare and strong PokŽmon in Houston, TX. See m...
# 1     From late 2014 Socium Marketplace will make sh...
# 2     Inspired by the smart, funny folks at @replyal...
# 3                                                   NaN
# 4                Inspiring cooks everywhere since 1956.
# ...                                                 ...
# 2792  Twitter CMO. Favorite title: Mama. Never, ever...
# 2793  I live in brooklyn, I'm a bike messenger, I pl...
# 2794                                     astrophysicist
# 2795  I'm quite out of my mind, actually, but people...
# 2796  I work for the people of the 6th District of T...
#
#                             url  followers_count  friends_count  listed_count  \
# 0     "https://t.co/dnWuDbFRkt"             1291              0            10
# 1                           NaN                1            349             0
# 2       https://t.co/P1e1o0m4KC             1086              0            14
# 3                           NaN               33              0             8
# 4                           NaN               11            745             0
# ...                         ...              ...            ...           ...
# 2792                        NaN            18998           2005           425
# 2793     http://t.co/CQkADdjfaw               32             54             0
# 2794     http://t.co/fgp5RYqr3T         45044433           7451         68157
# 2795                        NaN               16             64             1
# 2796     http://t.co/UcrfIiWGdl            22490            308          1342
#
#                             created_at  ...  default_profile  \
# 0     "Mon Jan 02 02:25:26 +0000 2017"  ...             True
# 1                        2/1/2016 7:37  ...             True
# 2       Fri Nov 20 18:53:22 +0000 2015  ...             True
# 3                      2/25/2015 20:11  ...             True
# 4                       1/1/2015 17:44  ...            False
# ...                                ...  ...              ...
# 2792                    1/10/2011 2:06  ...            False
# 2793    Sat Feb 19 12:12:42 +0000 2011  ...             True
# 2794                   7/18/2008 19:46  ...            False
# 2795                   8/11/2012 14:53  ...            False
# 2796    Mon Feb 02 20:30:20 +0000 2009  ...             True
#
#       default_profile_image  has_extended_profile                  name bot  \
# 0                     False                 False  "Houston PokŽ Alert"   1
# 1                     False                 False           Keri Nelson   1
# 2                     False                 False    Matt Lieber Is Bot   1
# 3                      True                 False    single cell papers   1
# 4                     False                 False          lucarivera16   1
# ...                     ...                   ...                   ...  ..
# 2792                  False                  True        Leslie Berland   0
# 2793                  False                 False    Samuel Littlefield   0
# 2794                  False                 False          jimmy fallon   0
# 2795                  False                  True        Tammas Foxdene   0
# 2796                  False                  True            Joe Barton   0
#
#       screen_name_binary  name_binary description_binary status_binary  \
# 0                   True        False              False          True
# 1                   True        False              False         False
# 2                   True         True               True          True
# 3                   True         True              False         False
# 4                  False        False               True         False
# ...                  ...          ...                ...           ...
# 2792               False        False              False         False
# 2793               False        False               True         False
# 2794               False        False              False         False
# 2795               False        False              False         False
# 2796               False        False              False         False
#
#       listed_count_binary
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# ...                   ...
# 2792                 True
# 2793                 True
# 2794                False
# 2795                 True
# 2796                 True
#
# [2797 rows x 25 columns]

# %%
X_train.head()
# Out:
#       screen_name_binary  name_binary  description_binary  status_binary  \
# 1508               False        False               False          False
# 412                 True         True                True          False
# 899                False        False               False          False
# 882                False        False                True          False
# 1091                True         True                True           True
#
#       verified  followers_count  friends_count  statuses_count  \
# 1508     False              328           1875            3335
# 412      False               50              0             926
# 899      False              364              0           25220
# 882      False               62              1            1760
# 1091     False              320              4            5570
#
#       listed_count_binary
# 1508                 True
# 412                  True
# 899                  True
# 882                  True
# 1091                 True

# %%
dt.predict([[True,True,True,False,False,50,0,926,True]])
# Out:
# C:\Users\YUVANSHU\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)
